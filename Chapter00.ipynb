# %% [markdown]
# <table style="background-color: #FFFFFF; border: 1px solid #000000; width: 100%; padding: 2px;"><tr style="background-color: #FFFFFF;"><td style="border: 1px solid #000000;"><center><font size="+5" color="#009900"><b>Jedi Academy of Python</b></font></center><br><br><br><br><div align="left"><b>Instructor:</b> Marc Hermon<br>Urbandale High School<br><a href="http://EngineeringU.com">EngineeringU.com</a></div></td><td style="border: 1px solid #000000;"><center><img src="http://www.hermonswebsites.com/PyNotebooks/Python/sithmedium.png"><font face="courier" size="+1" color="green"><b>print</b>(<font color="red">"Beware of the Ssssith!"</font>)</font></center></td></tr></table>

# %% [markdown]
# <table  style="background-color: #FFFFFF; border: 1px solid #000000; width: 100%; padding: 2px; text-align: left;">
# <tr style="background-color: #FFFFFF;"><td style="vertical-align: top; text-align: left; border: 1px solid #000000;">
# <b><u><font size="+2">Python for Younglings</font></u></b><br><br>
# <font size="+1">
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter01.ipynb">Chapter 01: Variable Types and Operators</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;iPython Session Log File
# <br><br>
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter02.ipynb">Chapter 02: Printing and User Input</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Temperature Program<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Trapezoid Program<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Grading Program
# <br><br>
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter03.ipynb">Chapter 03: If-Else Structures</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Quiz Master Project<br><br>
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter04.ipynb">Chapter 04: Looping and Random Numbers</a><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Coin Toss<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Roshambo<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Camel Project
# <br><br>
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter05.ipynb">Chapter 05: Lists, Tuples and Strings</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Adventure Project
# <br><br>
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter06.ipynb">Chapter 06: Functions</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Min( ) Function<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Box( ) Function<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Find( ) Function<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;FIZZBUZZ( ) Function<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;10,000# Program
# <br><br>
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter07.ipynb">Chapter 07: Text Formatting</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Formatting Fibonacci
# <br><br>
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter08.ipynb">Chapter 08: Version Control - GitHub</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Fork, Clone and Branch from Github
# <br><br>
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter09.ipynb">Chapter 09: Iterative Prisoner's Dilemma</a>
# </font>
# </td><td style="vertical-align: top; text-align: left; border: 1px solid #000000;">
# <b><u><font size="+2">Python for Padawans</font></u></b><br><br>
# <font size="+1">
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter10.ipynb">Chapter 10: Classes, Objects and Methods</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Classy Boats
# <br><br>
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter11.ipynb">Chapter 11: Libraries or Modules</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;My Library
# <br><br>
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter12.ipynb">Chapter 12: The Matplotlib Module</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Line Chart<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;American Flag<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Histogram<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Pie Chart
# <br><br>
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter13.ipynb">Chapter 13: Exception Handling</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;My Excel Project
# <br><br>
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter14.ipynb">Chapter 14: Manipulating Images</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J-Hawk Scholar
# <br><br>
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter15.ipynb">Chapter 15: Playing with Pixels</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Pixel Dust
# <br><br>
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter16.ipynb">Chapter 16: Python Imaging Library (PIL)</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Eyes of the Sith<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;May the Compression Force Be With You
# <br><br>
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter17.ipynb">Chapter 17: Image Algorithms</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Framing Star Wars Project
# <br><br>
# </font><b><u><font size="+2">Python for Jedi Knights</font></u></b><br><br>
# <font size="+1">
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter18.ipynb">Chapter 18: Graphics</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Python Picasso Project
# <br><br>
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter19.ipynb">Chapter 19: MVC Pattern</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Position Changer
# <br><br>
# <a href="http://nbviewer.ipython.org/github/CSP-UHS/Hermons_Book_of_Python/blob/master/Chapter20.ipynb">Chapter 20: More GUI</a>
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Color Explorer<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Canvas Art<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Animated Ball
# <br><br>
# </font>
# </td></tr></table>
